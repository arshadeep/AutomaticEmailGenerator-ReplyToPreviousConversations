# %%
#for Sending a mail
import pandas as pd
excel_file=r'Path_of_File'
dt=pd.read_excel(excel_file,sheet_name='Sheet1')
dt=dt.values.tolist()
print(dt)
s="<table style='border-style:solid;border-width:1px;border-collapse: collapse'>"
for row in dt:
    s+='<tr>'
    for column in row:
        s+="<td style='border-style:solid;border-width:1px;border-collapse: collapse'>"+str(column)+'<td>'
    s+='</tr>'
s+='</table>'
print(s)
dx=str(dt)
print(type(dx))
print(dx)
import win32com.client as win32
outlook = win32.Dispatch('outlook.application') 
mail = outlook.CreateItem(0)                    
mail.To = 'MailId_1;MailId_2'
mail.CC='Optional'
mail.Subject = 'Subject'
mail.Body = 'Message body'
mail.HTMLBody = "<p>Your Message</p>" #this field is optional
mail.Send()
import os
#optional
os.remove(r'path')
# Out:
# Cannot get security assertion for user sesa577701@se.com from https://ping-sso.schneider-electric.com:443/idp/eyJ2c2lkIjoic2UuY29tIn0=/sts.wst
# An error occurred while retrieving auth cookies from https://teams.microsoft.com/_forms/default.aspx?wa=wsignin1.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-28ec9c216c3c> in <module>
#       9
#      10 ctx_auth = AuthenticationContext(url)
# ---> 11 if ctx_auth.acquire_token_for_user(client_id, client_secret):
#      12     ctx = ClientContext(url, ctx_auth)
#      13     with open(filename, 'wb') as output_file:
#
# C:\ProgramData\Anaconda3\lib\site-packages\office365\runtime\auth\authentication_context.py in acquire_token_for_user(self, username, password)
#      36                 authority=authority_url,
#      37                 client_credential=credentials,
# ---> 38             )
#      39             result = app.acquire_token_for_client(scopes)
#      40             return TokenResponse.from_json(result)
#
# ValueError: Acquire token failed: An error occurred while retrieving auth cookies from https://teams.microsoft.com/_forms/default.aspx?wa=wsignin1.0

# %%
import pandas as pd
import win32com.client as win32
excel_file=r'path'
dt=pd.read_excel(excel_file,sheet_name='Sheet1')
dt=dt.values.tolist()
print(dt)
s="<table style='border-style:solid;border-width:1px;border-collapse: collapse'>"
for row in dt:
    s+='<tr>'
    for column in row:
        s+="<td style='border-style:solid;border-width:1px;border-collapse: collapse'>"+str(column)+'<td>'
    s+='</tr>'
s+='</table>'


#open and read the file after the appending:


from datetime import date


f = open("demofile2.txt", "r")
x=f.read()

today = date.today()

f = open("demofile2.txt", "w")
f.write(str(today.strftime("%d/%m/%Y")))
f.close()




# dd/mm/YY
d1 = today.strftime("%d/%m/%Y")
print("d1 =", d1)

outlook = win32.Dispatch("Outlook.Application").GetNamespace("MAPI")
sentItems = outlook.GetDefaultFolder(5) # "6" refers to the index of a folder - in this case,
                                    # the inbox. You can change that number to reference
                                    # any other folder

messages_sent = sentItems.Items

found = False
message_subject_to_find = 'Daily Teams Updates  '+x
print(message_subject_to_find)
subject_found = ''

for message in messages_sent: 
	# print('Message class: {}'.format(message.Class))
	# print('Message subject: {}'.format(message.Subject.encode("utf-8")))
	# Message class 43 -> mail
	if message.Class == 43:
		if message_subject_to_find in message.Subject:
			subject_found = message.Subject
			found = True
			a=message.Reply()
			print(a)
			a.HTMLBody="<p>Your message</p>"+a.HTMLBody
			a.Subject='subject  '+str(today.strftime("%d/%m/%Y"))
			a.To='mail_id'
			a.cc='mail_id'
			a.Send()
			break
            
if found:
  print('Done for this item !! -> {}'.format(subject_found))
else:
  print('Subject not found')

import os
#optional
os.remove(r'path of file')
